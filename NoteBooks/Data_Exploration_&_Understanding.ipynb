# %% [markdown]
# # Importing Libraries & load data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('../Project Info/Dataset/GUIDE_Train.csv')  # Load the dataset
df.head(3)
# Out:
#               Id  OrgId  IncidentId  AlertId                 Timestamp  \
# 0   180388628218      0         612   123247  2024-06-04T06:05:15.000Z
# 1   455266534868     88         326   210035  2024-06-14T03:01:25.000Z
# 2  1056561957389    809       58352   712507  2024-06-13T04:52:55.000Z
#
#    DetectorId  AlertTitle       Category MitreTechniques  IncidentGrade  ...  \
# 0           7           6  InitialAccess             NaN   TruePositive  ...
# 1          58          43   Exfiltration             NaN  FalsePositive  ...
# 2         423         298  InitialAccess           T1189  FalsePositive  ...
#
#   ResourceType Roles OSFamily OSVersion  AntispamDirection  SuspicionLevel  \
# 0          NaN   NaN        5        66                NaN             NaN
# 1          NaN   NaN        5        66                NaN             NaN
# 2          NaN   NaN        5        66                NaN      Suspicious
#
#    LastVerdict  CountryCode  State   City
# ...

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
df.info()   # dataset information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9516837 entries, 0 to 9516836
# Data columns (total 45 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   Id                  int64
#  1   OrgId               int64
#  2   IncidentId          int64
#  3   AlertId             int64
#  4   Timestamp           object
#  5   DetectorId          int64
#  6   AlertTitle          int64
#  7   Category            object
#  8   MitreTechniques     object
#  9   IncidentGrade       object
#  10  ActionGrouped       object
#  11  ActionGranular      object
#  12  EntityType          object
#  13  EvidenceRole        object
#  14  DeviceId            int64
#  15  Sha256              int64
#  16  IpAddress           int64
#  17  Url                 int64
#  18  AccountSid          int64
#  19  AccountUpn          int64
#  20  AccountObjectId     int64
#  21  AccountName         int64
#  22  DeviceName          int64
#  23  NetworkMessageId    int64
# ...

# %%
# Print the shape of the dataset
print(f"Dataset Shape: {df.shape}\n")
# Out:
# Dataset Shape: (9516837, 45)

# %%
df.describe()   # summary statistics
# Out:
#                  Id         OrgId    IncidentId       AlertId    DetectorId  \
# count  9.516837e+06  9.516837e+06  9.516837e+06  9.516837e+06  9.516837e+06
# mean   8.425494e+11  1.815800e+02  7.066349e+04  4.065188e+05  1.106724e+02
# std    4.962499e+11  3.867784e+02  1.208369e+05  4.592827e+05  4.351038e+02
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    4.123169e+11  1.000000e+01  5.040000e+02  2.324200e+04  2.000000e+00
# 50%    8.418136e+11  4.500000e+01  1.033600e+04  2.166520e+05  9.000000e+00
# 75%    1.271310e+12  1.710000e+02  8.432900e+04  6.715770e+05  4.500000e+01
# max    1.709397e+12  6.147000e+03  5.997060e+05  1.721456e+06  9.522000e+03
#
#          AlertTitle      DeviceId        Sha256     IpAddress           Url  \
# count  9.516837e+06  9.516837e+06  9.516837e+06  9.516837e+06  9.516837e+06
# mean   2.947315e+03  9.566476e+04  1.287191e+05  2.857506e+05  1.503317e+05
# ...

# %%
# Distribution of the target variable
df['IncidentGrade'].value_counts(normalize=True)
# Out:
# IncidentGrade
# BenignPositive    0.434295
# TruePositive      0.351034
# FalsePositive     0.214671
# Name: proportion, dtype: float64

# %% [markdown]
# # Visualization

# %%
# Check the distribution of the IncidentGrade variable (if it exists in the dataset)
if 'IncidentGrade' in df.columns:  
    print("IncidentGrade Variable Distribution:")
    sns.countplot(df['IncidentGrade'])
    plt.title("Distribution of IncidentGrade Variable")
    plt.show()
# Out:
# IncidentGrade Variable Distribution:

# %%
# Check for class imbalance
if 'IncidentGrade' in df.columns:
    target_counts = df['IncidentGrade'].value_counts()
    plt.pie(target_counts, labels=target_counts.index, autopct='%1.1f%%', startangle=90)
    plt.title("Class Imbalance of IncidentGrade")
    plt.show()

# %%
# Top 10 Categories for Alert Titles
plt.figure(figsize=(10, 6))
alert_title_counts = df['AlertTitle'].value_counts().nlargest(10)
sns.barplot(x=alert_title_counts.values, y=alert_title_counts.index, hue=alert_title_counts.index, palette='plasma', legend=False)
plt.title("Top 10 Alert Titles")
plt.xlabel("Count")
plt.ylabel("Alert Title")
plt.show()

# %%
# Select only numerical columns
numerical_data = df.select_dtypes(include=[np.number])

# Calculate correlation matrix for numerical features
correlation_matrix = numerical_data.corr()

plt.figure(figsize=(20, 10))    # Set the size of the plot
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f") # Plot the correlation matrix
plt.title("Correlation Heatmap of Numerical Features")
plt.tight_layout()
plt.show()
